# %%
TRAIN_DATA_PATH = './../data/train-1.renju'
TRAIN_SIZE = 1984695
TEST_DATA_PATH = './../data/train-2.renju'
TEST_SIZE = 147230
BATCH_SIZE = 1000

POS_TO_LETTER = 'abcdefghijklmno'
LETTER_TO_POS = dict((let, pos) for pos, let in enumerate(POS_TO_LETTER))

# %%
def parse_data_file(data_path, ind):
    def convert_move_to_pos(move):
        move = move.strip()
        try:
            let, n = move[0], int(move[1:]) - 1
            return n, LETTER_TO_POS[let]
        except:
            return None
    
    def normalize_game_info(game_info):
        return game_info[0], [convert_move_to_pos(move) for move in game_info[1:] if convert_move_to_pos(move) is not None]
    
    raw_data = []
    cnt = -1
    print(data_path)
    with open(data_path) as ff:
        for line in ff:
            cnt += 1
            if cnt < ind * BATCH_SIZE:
                continue
            if cnt >= (ind + 1) * BATCH_SIZE:
                continue
            raw_data.append(line.strip('\n'))
            if cnt % 100 == 0:
                print('>({})'.format(str(cnt)), end='')
    print()
    return [normalize_game_info(game_info.split()) for game_info  in raw_data]

# %%
from board import Board
from config import WHITE, BLACK, change_color

import numpy as np
from copy import deepcopy
from random import shuffle
import json
import os

# %%
# Build list of data for training of testing
# One value of output array is a tuple containing
# a board state - array 15x15
# and an expert's move - np.array 225 with one value set to 1, corresponding to the chosen move
def generate_data(games):
    def generate_boards(game_info):
        winner = game_info[0]
        game = game_info[1]
        boards = list()
        board = Board()
        label = np.zeros((15, 15))
        color = BLACK
        is_win_state = 0
        if winner == 'black':
            is_win_state = 1
        elif winner == 'white':
            is_win_state = -1
        for move in game:
            label[move] = 1
            boards.append((
                deepcopy(board.get_board().tolist()),
                deepcopy(label.ravel().tolist()),
                [np.float64(is_win_state)]
            ))
            boards.append((
                deepcopy(np.rot90(board.get_board()).tolist()),
                deepcopy(np.rot90(label).ravel().tolist()),
                [np.float64(is_win_state)]
            ))
            boards.append((
                deepcopy(np.rot90(board.get_board(), 2).tolist()), 
                deepcopy(np.rot90(label, 2).ravel().tolist()),
                [np.float64(is_win_state)]
            ))
            boards.append((
                deepcopy(np.rot90(board.get_board(), 3).tolist()),
                deepcopy(np.rot90(label, 3).ravel().tolist()),
                [np.float64(is_win_state)]
            ))
            try:
                board.execute_move(move, color)
            except:
                boards.pop()
                boards.pop()
                boards.pop()
                boards.pop()
                break
            label[move] = 0
            color = change_color(color)
            is_win_state = -is_win_state
        return boards
            
    data = []
    cnt = 0
    for game in games:
        data.extend(generate_boards(game))
        cnt += 1
        if cnt % 100 == 0:
            print('-', end='')
    print()
    shuffle(data)
    return data

# %%
for ind in range((TRAIN_SIZE + BATCH_SIZE - 1) // BATCH_SIZE):
    if ind < 147:
        continue
    if os.path.isfile('./../renju_nn_train_data/renju_nn_train_data_{}.json'.format(str(ind))):
        continue
    print('STAGE: parse data file {}'.format(ind))
    train_game_data = parse_data_file(TRAIN_DATA_PATH, ind)
    print('STAGE: generate data')
    train_data = generate_data(train_game_data)
    with open('./../renju_nn_train_data/renju_nn_train_data_{}.json'.format(str(ind)), 'w') as f:
        json.dump(train_data, f)
    print('_____________________________________________________________________')
    print('Loaded batch {}'.format(str(ind)))
# Out:
# STAGE: parse data file 308
# ./../data/train-1.renju
# >(308000)>(308100)>(308200)>(308300)>(308400)>(308500)>(308600)>(308700)>(308800)>(308900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 308
# STAGE: parse data file 309
# ./../data/train-1.renju
# >(309000)>(309100)>(309200)>(309300)>(309400)>(309500)>(309600)>(309700)>(309800)>(309900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 309
# STAGE: parse data file 310
# ./../data/train-1.renju
# >(310000)>(310100)>(310200)>(310300)>(310400)>(310500)>(310600)>(310700)>(310800)>(310900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 310
# STAGE: parse data file 311
# ./../data/train-1.renju
# >(311000)>(311100)>(311200)>(311300)>(311400)>(311500)>(311600)>(311700)>(311800)>(311900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 311
# STAGE: parse data file 312
# ./../data/train-1.renju
# >(312000)>(312100)>(312200)>(312300)>(312400)>(312500)>(312600)>(312700)>(312800)>(312900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 312
# STAGE: parse data file 313
# ./../data/train-1.renju
# >(313000)>(313100)>(313200)>(313300)>(313400)>(313500)>(313600)>(313700)>(313800)>(313900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 313
# STAGE: parse data file 314
# ./../data/train-1.renju
# >(314000)>(314100)>(314200)>(314300)>(314400)>(314500)>(314600)>(314700)>(314800)>(314900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 314
# STAGE: parse data file 315
# ./../data/train-1.renju
# >(315000)>(315100)>(315200)>(315300)>(315400)>(315500)>(315600)>(315700)>(315800)>(315900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 315
# STAGE: parse data file 316
# ./../data/train-1.renju
# >(316000)>(316100)>(316200)>(316300)>(316400)>(316500)>(316600)>(316700)>(316800)>(316900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 316
# STAGE: parse data file 317
# ./../data/train-1.renju
# >(317000)>(317100)>(317200)>(317300)>(317400)>(317500)>(317600)>(317700)>(317800)>(317900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 317
# STAGE: parse data file 318
# ./../data/train-1.renju
# >(318000)>(318100)>(318200)>(318300)>(318400)>(318500)>(318600)>(318700)>(318800)>(318900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 318
# STAGE: parse data file 319
# ./../data/train-1.renju
# >(319000)>(319100)>(319200)>(319300)>(319400)>(319500)>(319600)>(319700)>(319800)>(319900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 319
# STAGE: parse data file 320
# ./../data/train-1.renju
# >(320000)>(320100)>(320200)>(320300)>(320400)>(320500)>(320600)>(320700)>(320800)>(320900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 320
# STAGE: parse data file 321
# ./../data/train-1.renju
# >(321000)>(321100)>(321200)>(321300)>(321400)>(321500)>(321600)>(321700)>(321800)>(321900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 321
# STAGE: parse data file 322
# ./../data/train-1.renju
# >(322000)>(322100)>(322200)>(322300)>(322400)>(322500)>(322600)>(322700)>(322800)>(322900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 322
# STAGE: parse data file 323
# ./../data/train-1.renju
# >(323000)>(323100)>(323200)>(323300)>(323400)>(323500)>(323600)>(323700)>(323800)>(323900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 323
# STAGE: parse data file 324
# ./../data/train-1.renju
# >(324000)>(324100)>(324200)>(324300)>(324400)>(324500)>(324600)>(324700)>(324800)>(324900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 324
# STAGE: parse data file 325
# ./../data/train-1.renju
# >(325000)>(325100)>(325200)>(325300)>(325400)>(325500)>(325600)>(325700)>(325800)>(325900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 325
# STAGE: parse data file 326
# ./../data/train-1.renju
# >(326000)>(326100)>(326200)>(326300)>(326400)>(326500)>(326600)>(326700)>(326800)>(326900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 326
# STAGE: parse data file 327
# ./../data/train-1.renju
# >(327000)>(327100)>(327200)>(327300)>(327400)>(327500)>(327600)>(327700)>(327800)>(327900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 327
# STAGE: parse data file 328
# ./../data/train-1.renju
# >(328000)>(328100)>(328200)>(328300)>(328400)>(328500)>(328600)>(328700)>(328800)>(328900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 328
# STAGE: parse data file 329
# ./../data/train-1.renju
# >(329000)>(329100)>(329200)>(329300)>(329400)>(329500)>(329600)>(329700)>(329800)>(329900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 329
# STAGE: parse data file 330
# ./../data/train-1.renju
# >(330000)>(330100)>(330200)>(330300)>(330400)>(330500)>(330600)>(330700)>(330800)>(330900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 330
# STAGE: parse data file 331
# ./../data/train-1.renju
# >(331000)>(331100)>(331200)>(331300)>(331400)>(331500)>(331600)>(331700)>(331800)>(331900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 331
# STAGE: parse data file 332
# ./../data/train-1.renju
# >(332000)>(332100)>(332200)>(332300)>(332400)>(332500)>(332600)>(332700)>(332800)>(332900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 332
# STAGE: parse data file 333
# ./../data/train-1.renju
# >(333000)>(333100)>(333200)>(333300)>(333400)>(333500)>(333600)>(333700)>(333800)>(333900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 333
# STAGE: parse data file 334
# ./../data/train-1.renju
# >(334000)>(334100)>(334200)>(334300)>(334400)>(334500)>(334600)>(334700)>(334800)>(334900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 334
# STAGE: parse data file 335
# ./../data/train-1.renju
# >(335000)>(335100)>(335200)>(335300)>(335400)>(335500)>(335600)>(335700)>(335800)>(335900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 335
# STAGE: parse data file 336
# ./../data/train-1.renju
# >(336000)>(336100)>(336200)>(336300)>(336400)>(336500)>(336600)>(336700)>(336800)>(336900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 336
# STAGE: parse data file 337
# ./../data/train-1.renju
# >(337000)>(337100)>(337200)>(337300)>(337400)>(337500)>(337600)>(337700)>(337800)>(337900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 337
# STAGE: parse data file 338
# ./../data/train-1.renju
# >(338000)>(338100)>(338200)>(338300)>(338400)>(338500)>(338600)>(338700)>(338800)>(338900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 338
# STAGE: parse data file 339
# ./../data/train-1.renju
# >(339000)>(339100)>(339200)>(339300)>(339400)>(339500)>(339600)>(339700)>(339800)>(339900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 339
# STAGE: parse data file 340
# ./../data/train-1.renju
# >(340000)>(340100)>(340200)>(340300)>(340400)>(340500)>(340600)>(340700)>(340800)>(340900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 340
# STAGE: parse data file 341
# ./../data/train-1.renju
# >(341000)>(341100)>(341200)>(341300)>(341400)>(341500)>(341600)>(341700)>(341800)>(341900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 341
# STAGE: parse data file 342
# ./../data/train-1.renju
# >(342000)>(342100)>(342200)>(342300)>(342400)>(342500)>(342600)>(342700)>(342800)>(342900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 342
# STAGE: parse data file 343
# ./../data/train-1.renju
# >(343000)>(343100)>(343200)>(343300)>(343400)>(343500)>(343600)>(343700)>(343800)>(343900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 343
# STAGE: parse data file 344
# ./../data/train-1.renju
# >(344000)>(344100)>(344200)>(344300)>(344400)>(344500)>(344600)>(344700)>(344800)>(344900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 344
# STAGE: parse data file 345
# ./../data/train-1.renju
# >(345000)>(345100)>(345200)>(345300)>(345400)>(345500)>(345600)>(345700)>(345800)>(345900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 345
# STAGE: parse data file 346
# ./../data/train-1.renju
# >(346000)>(346100)>(346200)>(346300)>(346400)>(346500)>(346600)>(346700)>(346800)>(346900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 346
# STAGE: parse data file 347
# ./../data/train-1.renju
# >(347000)>(347100)>(347200)>(347300)>(347400)>(347500)>(347600)>(347700)>(347800)>(347900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 347
# STAGE: parse data file 348
# ./../data/train-1.renju
# >(348000)>(348100)>(348200)>(348300)>(348400)>(348500)>(348600)>(348700)>(348800)>(348900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 348
# STAGE: parse data file 349
# ./../data/train-1.renju
# >(349000)>(349100)>(349200)>(349300)>(349400)>(349500)>(349600)>(349700)>(349800)>(349900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 349
# STAGE: parse data file 350
# ./../data/train-1.renju
# >(350000)>(350100)>(350200)>(350300)>(350400)>(350500)>(350600)>(350700)>(350800)>(350900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 350
# STAGE: parse data file 351
# ./../data/train-1.renju
# >(351000)>(351100)>(351200)>(351300)>(351400)>(351500)>(351600)>(351700)>(351800)>(351900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 351
# STAGE: parse data file 352
# ./../data/train-1.renju
# >(352000)>(352100)>(352200)>(352300)>(352400)>(352500)>(352600)>(352700)>(352800)>(352900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 352
# STAGE: parse data file 353
# ./../data/train-1.renju
# >(353000)>(353100)>(353200)>(353300)>(353400)>(353500)>(353600)>(353700)>(353800)>(353900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 353
# STAGE: parse data file 354
# ./../data/train-1.renju
# >(354000)>(354100)>(354200)>(354300)>(354400)>(354500)>(354600)>(354700)>(354800)>(354900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 354
# STAGE: parse data file 355
# ./../data/train-1.renju
# >(355000)>(355100)>(355200)>(355300)>(355400)>(355500)>(355600)>(355700)>(355800)>(355900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 355
# STAGE: parse data file 356
# ./../data/train-1.renju
# >(356000)>(356100)>(356200)>(356300)>(356400)>(356500)>(356600)>(356700)>(356800)>(356900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 356
# STAGE: parse data file 357
# ./../data/train-1.renju
# >(357000)>(357100)>(357200)>(357300)>(357400)>(357500)>(357600)>(357700)>(357800)>(357900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 357
# STAGE: parse data file 358
# ./../data/train-1.renju
# >(358000)>(358100)>(358200)>(358300)>(358400)>(358500)>(358600)>(358700)>(358800)>(358900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 358
# STAGE: parse data file 359
# ./../data/train-1.renju
# >(359000)>(359100)>(359200)>(359300)>(359400)>(359500)>(359600)>(359700)>(359800)>(359900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 359
# STAGE: parse data file 360
# ./../data/train-1.renju
# >(360000)>(360100)>(360200)>(360300)>(360400)>(360500)>(360600)>(360700)>(360800)>(360900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 360
# STAGE: parse data file 361
# ./../data/train-1.renju
# >(361000)>(361100)>(361200)>(361300)>(361400)>(361500)>(361600)>(361700)>(361800)>(361900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 361
# STAGE: parse data file 362
# ./../data/train-1.renju
# >(362000)>(362100)>(362200)>(362300)>(362400)>(362500)>(362600)>(362700)>(362800)>(362900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 362
# STAGE: parse data file 363
# ./../data/train-1.renju
# >(363000)>(363100)>(363200)>(363300)>(363400)>(363500)>(363600)>(363700)>(363800)>(363900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 363
# STAGE: parse data file 364
# ./../data/train-1.renju
# >(364000)>(364100)>(364200)>(364300)>(364400)>(364500)>(364600)>(364700)>(364800)>(364900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 364
# STAGE: parse data file 365
# ./../data/train-1.renju
# >(365000)>(365100)>(365200)>(365300)>(365400)>(365500)>(365600)>(365700)>(365800)>(365900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 365
# STAGE: parse data file 366
# ./../data/train-1.renju
# >(366000)>(366100)>(366200)>(366300)>(366400)>(366500)>(366600)>(366700)>(366800)>(366900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 366
# STAGE: parse data file 367
# ./../data/train-1.renju
# >(367000)>(367100)>(367200)>(367300)>(367400)>(367500)>(367600)>(367700)>(367800)>(367900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 367
# STAGE: parse data file 368
# ./../data/train-1.renju
# >(368000)>(368100)>(368200)>(368300)>(368400)>(368500)>(368600)>(368700)>(368800)>(368900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 368
# STAGE: parse data file 369
# ./../data/train-1.renju
# >(369000)>(369100)>(369200)>(369300)>(369400)>(369500)>(369600)>(369700)>(369800)>(369900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 369
# STAGE: parse data file 370
# ./../data/train-1.renju
# >(370000)>(370100)>(370200)>(370300)>(370400)>(370500)>(370600)>(370700)>(370800)>(370900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 370
# STAGE: parse data file 371
# ./../data/train-1.renju
# >(371000)>(371100)>(371200)>(371300)>(371400)>(371500)>(371600)>(371700)>(371800)>(371900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 371
# STAGE: parse data file 372
# ./../data/train-1.renju
# >(372000)>(372100)>(372200)>(372300)>(372400)>(372500)>(372600)>(372700)>(372800)>(372900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 372
# STAGE: parse data file 373
# ./../data/train-1.renju
# >(373000)>(373100)>(373200)>(373300)>(373400)>(373500)>(373600)>(373700)>(373800)>(373900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 373
# STAGE: parse data file 374
# ./../data/train-1.renju
# >(374000)>(374100)>(374200)>(374300)>(374400)>(374500)>(374600)>(374700)>(374800)>(374900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 374
# STAGE: parse data file 375
# ./../data/train-1.renju
# >(375000)>(375100)>(375200)>(375300)>(375400)>(375500)>(375600)>(375700)>(375800)>(375900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 375
# STAGE: parse data file 376
# ./../data/train-1.renju
# >(376000)>(376100)>(376200)>(376300)>(376400)>(376500)>(376600)>(376700)>(376800)>(376900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 376
# STAGE: parse data file 377
# ./../data/train-1.renju
# >(377000)>(377100)>(377200)>(377300)>(377400)>(377500)>(377600)>(377700)>(377800)>(377900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 377
# STAGE: parse data file 378
# ./../data/train-1.renju
# >(378000)>(378100)>(378200)>(378300)>(378400)>(378500)>(378600)>(378700)>(378800)>(378900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 378
# STAGE: parse data file 379
# ./../data/train-1.renju
# >(379000)>(379100)>(379200)>(379300)>(379400)>(379500)>(379600)>(379700)>(379800)>(379900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 379
# STAGE: parse data file 380
# ./../data/train-1.renju
# >(380000)>(380100)>(380200)>(380300)>(380400)>(380500)>(380600)>(380700)>(380800)>(380900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 380
# STAGE: parse data file 381
# ./../data/train-1.renju
# >(381000)>(381100)>(381200)>(381300)>(381400)>(381500)>(381600)>(381700)>(381800)>(381900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 381
# STAGE: parse data file 382
# ./../data/train-1.renju
# >(382000)>(382100)>(382200)>(382300)>(382400)>(382500)>(382600)>(382700)>(382800)>(382900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 382
# STAGE: parse data file 383
# ./../data/train-1.renju
# >(383000)>(383100)>(383200)>(383300)>(383400)>(383500)>(383600)>(383700)>(383800)>(383900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 383
# STAGE: parse data file 384
# ./../data/train-1.renju
# >(384000)>(384100)>(384200)>(384300)>(384400)>(384500)>(384600)>(384700)>(384800)>(384900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 384
# STAGE: parse data file 385
# ./../data/train-1.renju
# >(385000)>(385100)>(385200)>(385300)>(385400)>(385500)>(385600)>(385700)>(385800)>(385900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 385
# STAGE: parse data file 386
# ./../data/train-1.renju
# >(386000)>(386100)>(386200)>(386300)>(386400)>(386500)>(386600)>(386700)>(386800)>(386900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 386
# STAGE: parse data file 387
# ./../data/train-1.renju
# >(387000)>(387100)>(387200)>(387300)>(387400)>(387500)>(387600)>(387700)>(387800)>(387900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 387
# STAGE: parse data file 388
# ./../data/train-1.renju
# >(388000)>(388100)>(388200)>(388300)>(388400)>(388500)>(388600)>(388700)>(388800)>(388900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 388
# STAGE: parse data file 389
# ./../data/train-1.renju
# >(389000)>(389100)>(389200)>(389300)>(389400)>(389500)>(389600)>(389700)>(389800)>(389900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 389
# STAGE: parse data file 390
# ./../data/train-1.renju
# >(390000)>(390100)>(390200)>(390300)>(390400)>(390500)>(390600)>(390700)>(390800)>(390900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 390
# STAGE: parse data file 391
# ./../data/train-1.renju
# >(391000)>(391100)>(391200)>(391300)>(391400)>(391500)>(391600)>(391700)>(391800)>(391900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 391
# STAGE: parse data file 392
# ./../data/train-1.renju
# >(392000)>(392100)>(392200)>(392300)>(392400)>(392500)>(392600)>(392700)>(392800)>(392900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 392
# STAGE: parse data file 393
# ./../data/train-1.renju
# >(393000)>(393100)>(393200)>(393300)>(393400)>(393500)>(393600)>(393700)>(393800)>(393900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 393
# STAGE: parse data file 394
# ./../data/train-1.renju
# >(394000)>(394100)>(394200)>(394300)>(394400)>(394500)>(394600)>(394700)>(394800)>(394900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 394
# STAGE: parse data file 395
# ./../data/train-1.renju
# >(395000)>(395100)>(395200)>(395300)>(395400)>(395500)>(395600)>(395700)>(395800)>(395900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 395
# STAGE: parse data file 396
# ./../data/train-1.renju
# >(396000)>(396100)>(396200)>(396300)>(396400)>(396500)>(396600)>(396700)>(396800)>(396900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 396
# STAGE: parse data file 397
# ./../data/train-1.renju
# >(397000)>(397100)>(397200)>(397300)>(397400)>(397500)>(397600)>(397700)>(397800)>(397900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 397
# STAGE: parse data file 398
# ./../data/train-1.renju
# >(398000)>(398100)>(398200)>(398300)>(398400)>(398500)>(398600)>(398700)>(398800)>(398900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 398
# STAGE: parse data file 399
# ./../data/train-1.renju
# >(399000)>(399100)>(399200)>(399300)>(399400)>(399500)>(399600)>(399700)>(399800)>(399900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 399
# STAGE: parse data file 400
# ./../data/train-1.renju
# >(400000)>(400100)>(400200)>(400300)>(400400)>(400500)>(400600)>(400700)>(400800)>(400900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 400
# STAGE: parse data file 401
# ./../data/train-1.renju
# >(401000)>(401100)>(401200)>(401300)>(401400)>(401500)>(401600)>(401700)>(401800)>(401900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 401
# STAGE: parse data file 402
# ./../data/train-1.renju
# >(402000)>(402100)>(402200)>(402300)>(402400)>(402500)>(402600)>(402700)>(402800)>(402900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 402
# STAGE: parse data file 403
# ./../data/train-1.renju
# >(403000)>(403100)>(403200)>(403300)>(403400)>(403500)>(403600)>(403700)>(403800)>(403900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 403
# STAGE: parse data file 404
# ./../data/train-1.renju
# >(404000)>(404100)>(404200)>(404300)>(404400)>(404500)>(404600)>(404700)>(404800)>(404900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 404
# STAGE: parse data file 405
# ./../data/train-1.renju
# >(405000)>(405100)>(405200)>(405300)>(405400)>(405500)>(405600)>(405700)>(405800)>(405900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 405
# STAGE: parse data file 406
# ./../data/train-1.renju
# >(406000)>(406100)>(406200)>(406300)>(406400)>(406500)>(406600)>(406700)>(406800)>(406900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 406
# STAGE: parse data file 407
# ./../data/train-1.renju
# >(407000)>(407100)>(407200)>(407300)>(407400)>(407500)>(407600)>(407700)>(407800)>(407900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 407
# STAGE: parse data file 408
# ./../data/train-1.renju
# >(408000)>(408100)>(408200)>(408300)>(408400)>(408500)>(408600)>(408700)>(408800)>(408900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 408
# STAGE: parse data file 409
# ./../data/train-1.renju
# >(409000)>(409100)>(409200)>(409300)>(409400)>(409500)>(409600)>(409700)>(409800)>(409900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 409
# STAGE: parse data file 410
# ./../data/train-1.renju
# >(410000)>(410100)>(410200)>(410300)>(410400)>(410500)>(410600)>(410700)>(410800)>(410900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 410
# STAGE: parse data file 411
# ./../data/train-1.renju
# >(411000)>(411100)>(411200)>(411300)>(411400)>(411500)>(411600)>(411700)>(411800)>(411900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 411
# STAGE: parse data file 412
# ./../data/train-1.renju
# >(412000)>(412100)>(412200)>(412300)>(412400)>(412500)>(412600)>(412700)>(412800)>(412900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 412
# STAGE: parse data file 413
# ./../data/train-1.renju
# >(413000)>(413100)>(413200)>(413300)>(413400)>(413500)>(413600)>(413700)>(413800)>(413900)
# STAGE: generate data
# ----------
# _____________________________________________________________________
# Loaded batch 413
# STAGE: parse data file 414
# ./../data/train-1.renju
# >(414000)>(414100)>(414200)>(414300)>(414400)>(414500)>(414600)>(414700)>(414800)>(414900)
# STAGE: generate data
# ----------
